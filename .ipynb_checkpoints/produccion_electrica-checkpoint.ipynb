# %% [markdown]
# ## Producción eléctrica en España  `2015-2022`

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

from datetime import datetime as dt

import requests
import json

import time
from tqdm import tqdm

import warnings
warnings.filterwarnings('ignore')

# %%
# %run main.py

# %% [markdown]
# ## Generación eléctrica
# De `REData API` (API de Red Eléctrica Española) se extrae la `producción por tecnología` de electricidad desde `2015 hasta la fecha actual`. https://www.ree.es/es/apidatos

# %% [markdown]
# `FECHA ACTUAL`

# %%
today=dt.now().isoformat()[:10]
today
# Out:
# '2022-09-28'

# %% [markdown]
# `PRODUCCIÓN ENERGÍA 2015-2022`

# %%
df_2015=api_produccion('2015-01-01','2015-12-31')
df_2016=api_produccion('2016-01-01','2016-12-31')
df_2017=api_produccion('2017-01-01','2017-12-31')
df_2018=api_produccion('2018-01-01','2018-12-31')
df_2019=api_produccion('2019-01-01','2019-12-31')
df_2020=api_produccion('2020-01-01','2020-12-31')
df_2021=api_produccion('2021-01-01','2021-12-31')
df_2022=api_produccion_v2('2022-01-01',today)
# Out:
# Código de respuesta: 200. Datos desde 2015-01-01 hasta 2015-12-31. ¡REQUEST ACCEPTED!
# Código de respuesta: 200. Datos desde 2016-01-01 hasta 2016-12-31. ¡REQUEST ACCEPTED!
# Código de respuesta: 200. Datos desde 2017-01-01 hasta 2017-12-31. ¡REQUEST ACCEPTED!
# Código de respuesta: 200. Datos desde 2018-01-01 hasta 2018-12-31. ¡REQUEST ACCEPTED!
# Código de respuesta: 200. Datos desde 2019-01-01 hasta 2019-12-31. ¡REQUEST ACCEPTED!
# Código de respuesta: 200. Datos desde 2020-01-01 hasta 2020-12-31. ¡REQUEST ACCEPTED!
# Código de respuesta: 200. Datos desde 2021-01-01 hasta 2021-12-31. ¡REQUEST ACCEPTED!
# Código de respuesta: 200. Datos desde 2022-01-01 hasta 2022-09-28. ¡REQUEST ACCEPTED!

# %% [markdown]
# ------------------------------

# %% [markdown]
# `UNIÓN Y MODIFICACIÓN DE LOS DATAFRAMES`

# %%
lista_años=[df_2015,df_2016,df_2017,df_2018,df_2019,df_2020,df_2021,df_2022]
 
df_produccion=pd.concat(lista_años, ignore_index=True)
df_produccion.index=range(df_produccion.shape[0])
df_produccion['Fecha']=pd.to_datetime(df_produccion['Fecha'])
df_produccion=df_produccion.set_index('Fecha')
modify_zero(df_produccion)
# Out:
#             Hidraulica  Turbina_bombeo     Nuclear      Carbon  \
# Fecha
# 2015-01-01   71096.101        7717.717  170691.638  110401.621
# 2015-01-02  101890.114       19226.148  170694.173  145824.697
# 2015-01-03   82919.726        7346.234  170721.569  155672.299
# 2015-01-04   69056.368        8548.913  170722.657  143359.372
# 2015-01-05  104975.898        3887.742  170748.753  169891.449
# ...                ...             ...         ...         ...
# 2022-09-24   54777.400        7739.900  165323.800   21603.600
# 2022-09-25   48141.600        6331.800  160813.900   20333.200
# 2022-09-26   47071.100        7415.700  142863.400   26849.800
# 2022-09-27   21542.600        8718.700  142715.200   25079.100
# 2022-09-28     904.100        1382.000    5969.100    1215.000
#
#             Motores_diesel  Turbina_de_gas  Turbina_de_vapor  Ciclo_combinado  \
# Fecha
# 2015-01-01        8505.139        1600.508          5714.393        77053.919
# 2015-01-02        8913.111        2529.759          6861.491        95763.421
# 2015-01-03        9023.196        1767.598          6380.726        80251.500
# 2015-01-04        8962.055        1324.084          6252.905        71946.853
# 2015-01-05        9090.126        1833.574          6911.216       112886.007
# ...                    ...             ...               ...              ...
# 2022-09-24        7405.462        2955.227          3313.440       155981.184
# 2022-09-25        7472.427        4677.593          2990.680       108599.341
# 2022-09-26        7035.184        2642.231          3351.320       195144.274
# 2022-09-27        5987.098        1789.340          3255.772       190510.629
# 2022-09-28         199.790          28.560           114.360         7407.740
#
#             Hidroeolica      Eolica  Solar_fotovoltaica  Solar_termica  \
# Fecha
# 2015-01-01        7.857   87789.031           19649.742       8548.067
# 2015-01-02        7.627   55056.104           18686.983       8283.537
# 2015-01-03        8.524   86066.315           20239.403       8520.620
# 2015-01-04        8.200   99284.874           19884.029       9279.768
# 2015-01-05        6.204   34499.671           17977.904       7636.251
# ...                 ...         ...                 ...            ...
# 2022-09-24        8.471  166451.225           85596.652      13430.990
# 2022-09-25        4.474  169161.067           76021.433      15278.360
# 2022-09-26       40.386  160188.894           87979.981      16368.457
# 2022-09-27       32.481  223143.676           99629.707      19049.420
# 2022-09-28        3.169    8247.733               0.900        448.000
#
#             Otras_renovables  Cogeneracion  Residuos_no_renovables  \
# Fecha
# 2015-01-01          8484.308     44583.988               4817.7325
# 2015-01-02          8744.023     60642.875               5272.1195
# 2015-01-03          9021.465     64876.719               5879.6560
# 2015-01-04          9213.517     62509.909               6227.5365
# 2015-01-05          9107.890     67436.854               6344.5685
# ...                      ...           ...                     ...
# 2022-09-24         11996.380     26550.480               3657.1000
# 2022-09-25         11653.580     23440.480               4085.5500
# 2022-09-26         11340.690     28534.580               4433.9500
# 2022-09-27         10299.490     28080.080               5631.8000
# 2022-09-28           456.300      1218.800                240.0000
#
#             Residuos_renovables  Generacion_total
# Fecha
# 2015-01-01            2362.1405        629023.902
# 2015-01-02            2348.2145        710744.397
# 2015-01-03            2388.4810        711084.031
# 2015-01-04            2366.1475        688947.188
# 2015-01-05            2332.1515        725566.259
# ...                         ...               ...
# 2022-09-24            1522.7000        728314.011
# 2022-09-25            1906.0500        660911.535
# 2022-09-26            2017.9500        743277.897
# 2022-09-27            2511.8000        787976.893
# 2022-09-28             103.7000         27939.252
#
# [2828 rows x 17 columns]

# %% [markdown]
# `Guardar csv`

# %%
df_produccion.to_csv('csv/produccion.csv')

# %% [markdown]
# ### Análisis variables

# %%
columnas=df_produccion.columns
stats_info(df_produccion,columnas)
# Out:
# Datos estadísticos de la variable Hidraulica:
# Calculando...
# Desviación estándard: 38188.948
# Primer Cuartil -> Q1: 48076.02075
# Tercer Cuartil -> Q3: 94454.14050000001
# Rango intercuartilico (IQR): 46378.12
# Se considera outlier valores superiores a 164021.321 e inferior a -21491.159
# Media: 75843.283
# Mediana: 66924.074
# Mínimo: 904.1
# Máximo: 212677.595
#
# Datos estadísticos de la variable Turbina_bombeo:
# Calculando...
# Desviación estándard: 5097.001
# Primer Cuartil -> Q1: 2835.559
# Tercer Cuartil -> Q3: 10134.17325
# Rango intercuartilico (IQR): 7298.614
# Se considera outlier valores superiores a 21082.094 e inferior a -8112.362
# Media: 6976.029
# Mediana: 6146.398499999999
# Mínimo: -61.078
# Máximo: 30484.42
#
# Datos estadísticos de la variable Nuclear:
# Calculando...
# Desviación estándard: 22060.03
# Primer Cuartil -> Q1: 141406.41275
# Tercer Cuartil -> Q3: 167915.071
# Rango intercuartilico (IQR): 26508.658
# Se considera outlier valores superiores a 207678.058 e inferior a 101643.426
# Media: 150668.956
# Mediana: 161505.0675
# Mínimo: 5969.1
# Máximo: 171364.778
#
# Datos estadísticos de la variable Carbon:
# Calculando...
# Desviación estándard: 62863.547
# Primer Cuartil -> Q1: 17154.3965
# Tercer Cuartil -> Q3: 129920.51024999999
# Rango intercuartilico (IQR): 112766.114
# Se considera outlier valores superiores a 299069.681 e inferior a -151994.774
# Media: 71017.889
# Mediana: 39396.4115
# Mínimo: -1038.624
# Máximo: 219168.124
#
# Datos estadísticos de la variable Motores_diesel:
# Calculando...
# Desviación estándard: 1568.821
# Primer Cuartil -> Q1: 7138.9845000000005
# Tercer Cuartil -> Q3: 9342.19
# Rango intercuartilico (IQR): 2203.206
# Se considera outlier valores superiores a 12646.999 e inferior a 3834.176
# Media: 8211.785
# Mediana: 8267.5545
# Mínimo: 199.79
# Máximo: 12026.109
#
# Datos estadísticos de la variable Turbina_de_gas:
# Calculando...
# Desviación estándard: 1015.624
# Primer Cuartil -> Q1: 1112.5145
# Tercer Cuartil -> Q3: 2592.52725
# Rango intercuartilico (IQR): 1480.013
# Se considera outlier valores superiores a 4812.547 e inferior a -1107.505
# Media: 1911.839
# Mediana: 1768.0835000000002
# Mínimo: -0.971
# Máximo: 5220.28
#
# Datos estadísticos de la variable Turbina_de_vapor:
# Calculando...
# Desviación estándard: 1945.143
# Primer Cuartil -> Q1: 3763.4987499999997
# Tercer Cuartil -> Q3: 7098.1767500000005
# Rango intercuartilico (IQR): 3334.678
# Se considera outlier valores superiores a 12100.194 e inferior a -1238.518
# Media: 5439.474
# Mediana: 5725.621
# Mínimo: 114.36
# Máximo: 9406.491
#
# Datos estadísticos de la variable Ciclo_combinado:
# Calculando...
# Desviación estándard: 67084.114
# Primer Cuartil -> Q1: 63187.38375
# Tercer Cuartil -> Q3: 149010.28125
# Rango intercuartilico (IQR): 85822.897
# Se considera outlier valores superiores a 277744.627 e inferior a -65546.962
# Media: 113214.017
# Mediana: 92357.332
# Mínimo: 1724.078
# Máximo: 396449.164
#
# Datos estadísticos de la variable Hidroeolica:
# Calculando...
# Desviación estándard: 41.868
# Primer Cuartil -> Q1: 17.6815
# Tercer Cuartil -> Q3: 86.893
# Rango intercuartilico (IQR): 69.212
# Se considera outlier valores superiores a 190.711 e inferior a -86.137
# Media: 54.934
# Mediana: 46.742000000000004
# Mínimo: -4.074
# Máximo: 155.042
#
# Datos estadísticos de la variable Eolica:
# Calculando...
# Desviación estándard: 76923.311
# Primer Cuartil -> Q1: 84105.24775000001
# Tercer Cuartil -> Q3: 188740.1195
# Rango intercuartilico (IQR): 104634.872
# Se considera outlier valores superiores a 345692.428 e inferior a -72847.06
# Media: 143263.376
# Mediana: 128162.349
# Mínimo: 1788.757
# Máximo: 429744.96
#
# Datos estadísticos de la variable Solar_fotovoltaica:
# Calculando...
# Desviación estándard: 24782.061
# Primer Cuartil -> Q1: 19841.56125
# Tercer Cuartil -> Q3: 40764.8015
# Rango intercuartilico (IQR): 20923.24
# Se considera outlier valores superiores a 72149.662 e inferior a -11543.299
# Media: 35561.13
# Mediana: 28299.338
# Mínimo: 0.054
# Máximo: 153025.236
#
# Datos estadísticos de la variable Solar_termica:
# Calculando...
# Desviación estándard: 9959.543
# Primer Cuartil -> Q1: 4174.66525
# Tercer Cuartil -> Q3: 22523.11925
# Rango intercuartilico (IQR): 18348.454
# Se considera outlier valores superiores a 50045.8 e inferior a -23348.016
# Media: 13461.496
# Mediana: 11780.9205
# Mínimo: 0.001
# Máximo: 33388.129
#
# Datos estadísticos de la variable Otras_renovables:
# Calculando...
# Desviación estándard: 1955.917
# Primer Cuartil -> Q1: 9640.07825
# Tercer Cuartil -> Q3: 12074.528
# Rango intercuartilico (IQR): 2434.45
# Se considera outlier valores superiores a 15726.203 e inferior a 5988.403
# Media: 10736.541
# Mediana: 10438.881
# Mínimo: 312.574
# Máximo: 15495.067
#
# Datos estadísticos de la variable Cogeneracion:
# Calculando...
# Desviación estándard: 11843.722
# Primer Cuartil -> Q1: 69396.122
# Tercer Cuartil -> Q3: 79317.55225
# Rango intercuartilico (IQR): 9921.43
# Se considera outlier valores superiores a 94199.697 e inferior a 54513.977
# Media: 72371.422
# Mediana: 74648.744
# Mínimo: 1218.8
# Máximo: 92024.398
#
# Datos estadísticos de la variable Residuos_no_renovables:
# Calculando...
# Desviación estándard: 1055.172
# Primer Cuartil -> Q1: 5667.1925
# Tercer Cuartil -> Q3: 7103.79075
# Rango intercuartilico (IQR): 1436.598
# Se considera outlier valores superiores a 9258.688 e inferior a 3512.296
# Media: 6378.816
# Mediana: 6484.8455
# Mínimo: 172.7135
# Máximo: 8820.699
#
# Datos estadísticos de la variable Residuos_renovables:
# Calculando...
# Desviación estándard: 480.318
# Primer Cuartil -> Q1: 2142.656625
# Tercer Cuartil -> Q3: 2613.433375
# Rango intercuartilico (IQR): 470.777
# Se considera outlier valores superiores a 3319.599 e inferior a 1436.491
# Media: 2295.408
# Mediana: 2446.59775
# Mínimo: 47.4165
# Máximo: 3041.922
#
# Datos estadísticos de la variable Generacion_total:
# Calculando...
# Desviación estándard: 84000.538
# Primer Cuartil -> Q1: 664989.89275
# Tercer Cuartil -> Q3: 769609.7860000001
# Rango intercuartilico (IQR): 104619.893
# Se considera outlier valores superiores a 926539.626 e inferior a 508060.053
# Media: 717402.862
# Mediana: 718719.2590000001
# Mínimo: 22520.888
# Máximo: 943229.9480000001

# %% [markdown]
# Existen valores bajos e incluso negativos los cuales corresponden a exportación de energía elétrica.

# %% [markdown]
# -----------------------------------------
# ### Visualización
# `TEMPORALIDAD`

# %%
for i in df_produccion.columns:
    figure(figsize=(15,3), dpi=80)
    plt.plot(df_produccion[i], color='slateblue', linewidth=0.5)
    plt.xlabel('Fecha')
    plt.ylabel(f'Energia [MWh]')
    plt.title(i)
    plt.savefig(f"images/Produccion_electrica_{i}.jpg",bbox_inches='tight',dpi=300)
    plt.legend('Demanda')
    plt.show()

# %% [markdown]
# `DISTRIBUCIÓN`

# %%
for i in df_produccion.columns:
    figure(figsize=(15,3), dpi=80)
    sns.histplot(df_produccion[i], kde=True, bins=25)
    plt.xlabel('Energía')
    plt.title(i)
    plt.show()

# %% [markdown]
# `COMPARATIVA DE ENERGÍAS RENOVABLES`

# %%
figure(figsize=(15,6), dpi=80)

labels_renovables=['Hidraulica','Turbina_bombeo','Hidroeolica','Eolica','Solar_fotovoltaica',
                   'Solar_termica','Otras_renovables','Residuos_renovables','Solar_termica']

plt.plot(df_produccion['Hidraulica'], color='blue', linewidth=0.5)
plt.plot(df_produccion['Turbina_bombeo'], color='red', linewidth=0.5)
plt.plot(df_produccion['Hidroeolica'], color='green', linewidth=0.5)
plt.plot(df_produccion['Eolica'], color='teal', linewidth=0.5)
plt.plot(df_produccion['Solar_fotovoltaica'], color='black', linewidth=0.5)
plt.plot(df_produccion['Solar_termica'], color='yellow', linewidth=0.5)
plt.plot(df_produccion['Otras_renovables'], color='orange', linewidth=0.5)
plt.plot(df_produccion['Residuos_renovables'], color='brown', linewidth=0.5)
plt.xlabel('Fecha')
plt.ylabel(f'Energia [MWh]')
plt.title(f'Comparativa de energías renovables')
plt.legend(labels_renovables, loc="lower left", bbox_to_anchor=(1.0,0.6))
plt.savefig(f"images/Energías_renovables_series_temporales.jpg",bbox_inches='tight',dpi=300)
plt.show()

# %% [markdown]
# `COMPARATIVA DE ENERGÍAS RENOVABLES (SIN EOLICA)`

# %%
figure(figsize=(15,6), dpi=80)

labels_renovables=['Hidraulica','Turbina_bombeo','Hidroeolica','Solar_fotovoltaica',
                   'Solar_termica','Otras_renovables','Residuos_renovables','Solar_termica']

plt.plot(df_produccion['Hidraulica'], color='blue', linewidth=0.5)
plt.plot(df_produccion['Turbina_bombeo'], color='red', linewidth=0.5)
plt.plot(df_produccion['Hidroeolica'], color='green', linewidth=0.5)
plt.plot(df_produccion['Solar_fotovoltaica'], color='black', linewidth=0.5)
plt.plot(df_produccion['Solar_termica'], color='yellow', linewidth=0.5)
plt.plot(df_produccion['Otras_renovables'], color='orange', linewidth=0.5)
plt.plot(df_produccion['Residuos_renovables'], color='brown', linewidth=0.5)
plt.xlabel('Fecha')
plt.ylabel(f'Energia [MWh]')
plt.title(f'Comparativa de energías renovables')
plt.legend(labels_renovables, loc="lower left", bbox_to_anchor=(1.0,0.65))
plt.savefig(f"images/Energías_renovables_series_temporales_wo_eolica.jpg",bbox_inches='tight',dpi=300)
plt.show()

# %% [markdown]
# `COMPARATIVA DE ENERGÍAS NO RENOVABLES`

# %%
figure(figsize=(15,6), dpi=80)

labels_no_renovables=['Nuclear','Carbon','Motores diesel','Turbina de gas','Turbina de vapor',
        'Ciclo combinado','Cogeneracion','Residuos no renovables']

plt.plot(df_produccion['Nuclear'], color='blue', linewidth=0.5)
plt.plot(df_produccion['Carbon'], color='red', linewidth=0.5)
plt.plot(df_produccion['Motores_diesel'], color='green', linewidth=0.5)
plt.plot(df_produccion['Turbina_de_gas'], color='magenta', linewidth=0.5)
plt.plot(df_produccion['Turbina_de_vapor'], color='black', linewidth=0.5)
plt.plot(df_produccion['Ciclo_combinado'], color='yellow', linewidth=0.5)
plt.plot(df_produccion['Cogeneracion'], color='orange', linewidth=0.5)
plt.plot(df_produccion['Residuos_no_renovables'], color='brown', linewidth=0.5)
plt.xlabel('Fecha')
plt.ylabel(f'Energia [MWh]')
plt.title(f'Comparativa de energías no renovables')
plt.legend(labels=labels_no_renovables, loc="lower left",bbox_to_anchor=(1.0,0.63))
plt.savefig(f"images/Energías__no_renovables_series_temporales.jpg",bbox_inches='tight',dpi=300)
plt.show()

# %% [markdown]
# `GRAFICO DE BARRAS ACUMULADAS POR AÑO`

# %%
lista_años=[2015,2016,2017,2018,2019,2020,2021,2022]

hidraulica_sum=[df_produccion[df_produccion['Hidraulica'].index.year==i]['Hidraulica'].sum() for i in lista_años]
turbina_bombeo_sum=[df_produccion[df_produccion['Turbina_bombeo'].index.year==i]['Turbina_bombeo'].sum() for i in lista_años]
nuclear_sum=[df_produccion[df_produccion['Nuclear'].index.year==i]['Nuclear'].sum() for i in lista_años]
carbon_sum=[df_produccion[df_produccion['Carbon'].index.year==i]['Carbon'].sum() for i in lista_años]
motores_diesel_sum=[df_produccion[df_produccion['Motores_diesel'].index.year==i]['Motores_diesel'].sum() for i in lista_años]
turbina_gas_sum=[df_produccion[df_produccion['Turbina_de_gas'].index.year==i]['Turbina_de_gas'].sum() for i in lista_años]
turbina_vapor_sum=[df_produccion[df_produccion['Turbina_de_vapor'].index.year==i]['Turbina_de_vapor'].sum() for i in lista_años]
ciclo_combinado_sum=[df_produccion[df_produccion['Ciclo_combinado'].index.year==i]['Ciclo_combinado'].sum() for i in lista_años]
hidroeolica_sum=[df_produccion[df_produccion['Hidroeolica'].index.year==i]['Hidroeolica'].sum() for i in lista_años]
eolica_sum=[df_produccion[df_produccion['Eolica'].index.year==i]['Eolica'].sum() for i in lista_años]
solar_fotovoltaica_sum=[df_produccion[df_produccion['Solar_fotovoltaica'].index.year==i]['Solar_fotovoltaica'].sum() for i in lista_años]
solar_termica_sum=[df_produccion[df_produccion['Solar_termica'].index.year==i]['Solar_termica'].sum() for i in lista_años]
otras_renovables_sum=[df_produccion[df_produccion['Otras_renovables'].index.year==i]['Otras_renovables'].sum() for i in lista_años]
cogeneracion_sum=[df_produccion[df_produccion['Cogeneracion'].index.year==i]['Cogeneracion'].sum() for i in lista_años]
residuos_no_renovables_sum=[df_produccion[df_produccion['Residuos_no_renovables'].index.year==i]['Residuos_no_renovables'].sum() for i in lista_años]
residuos_renovales_sum=[df_produccion[df_produccion['Residuos_renovables'].index.year==i]['Residuos_renovables'].sum() for i in lista_años]

lista_tecnologias_sum=['Año','Hidraulica','Turbina_bombeo','Nuclear','Carbon','Motores_diesel','Turbina_de_gas',
                   'Turbina_de_vapor','Ciclo_combinado','Hidroeolica','Eolica','Solar_fotovoltaica','Solar_termica',
                   'Otras_renovables','Cogeneracion','Residuos_no_renovables','Residuos_renovables']    

df_sum=pd.DataFrame(zip(lista_años, hidraulica_sum, turbina_bombeo_sum, nuclear_sum, 
                        carbon_sum, motores_diesel_sum, turbina_gas_sum, turbina_vapor_sum, 
                        ciclo_combinado_sum, hidroeolica_sum, eolica_sum, solar_fotovoltaica_sum, 
                        solar_termica_sum, otras_renovables_sum, cogeneracion_sum, residuos_no_renovables_sum, 
                        residuos_renovales_sum), columns=lista_tecnologias_sum)

df_sum=df_sum.set_index('Año')
df_sum
# Out:
#         Hidraulica  Turbina_bombeo       Nuclear        Carbon  \
# Año
# 2015  2.833324e+07     2876912.792  5.449860e+07  5.253443e+07
# 2016  3.607208e+07     3124949.714  5.585802e+07  3.714783e+07
# 2017  1.841088e+07     2240446.352  5.537588e+07  4.499508e+07
# 2018  3.404661e+07     1993564.064  5.305857e+07  3.722063e+07
# 2019  2.455954e+07     1640061.929  5.566081e+07  1.265842e+07
# 2020  3.050887e+07     2744446.235  5.559450e+07  5.015211e+06
# 2021  2.953026e+07     2633216.311  5.390069e+07  4.960089e+06
# 2022  1.302333e+07     2474612.458  4.214474e+07  6.306890e+06
#
#       Motores_diesel  Turbina_de_gas  Turbina_de_vapor  Ciclo_combinado  \
# Año
# 2015     3336173.641      913647.328       2215450.894     2.895263e+07
# 2016     3593516.274      614994.438       2528169.639     2.894256e+07
# 2017     3447752.567      868914.792       2667247.329     3.703217e+07
# 2018     3170439.095     1047951.388       2447498.803     2.994922e+07
# 2019     2828506.728      668942.988       2184094.616     5.512765e+07
# 2020     2392241.727      406020.732       1383923.144     4.395091e+07
# 2021     2510136.297      423011.230       1104205.729     4.444329e+07
# 2022     1944161.088      463197.449        852243.555     5.177081e+07
#
#       Hidroeolica        Eolica  Solar_fotovoltaica  Solar_termica  \
# Año
# 2015     8191.280  4.801408e+07        8.236409e+06   5.086328e+06
# 2016    17823.701  4.765657e+07        7.962554e+06   5.065071e+06
# 2017    20161.757  4.764402e+07        8.391072e+06   5.350116e+06
# 2018    23637.590  4.950946e+07        7.747063e+06   4.420137e+06
# 2019    23249.176  5.420501e+07        9.230702e+06   5.164187e+06
# 2020    19528.938  5.468013e+07        1.527381e+07   4.534635e+06
# 2021    23044.330  6.038125e+07        2.090603e+07   4.698037e+06
# 2022    19715.542  4.305831e+07        2.281923e+07   3.750599e+06
#
#       Otras_renovables  Cogeneracion  Residuos_no_renovables  \
# Año
# 2015       3425128.954  2.514544e+07            2.476596e+06
# 2016       3416073.447  2.584907e+07            2.600826e+06
# 2017       3602475.090  2.815552e+07            2.602406e+06
# 2018       3549068.963  2.894074e+07            2.429247e+06
# 2019       3609509.229  2.955177e+07            2.218348e+06
# 2020       4469348.673  2.697002e+07            2.012044e+06
# 2021       4705202.571  2.602830e+07            2.232148e+06
# 2022       3586130.428  1.402552e+07            1.467677e+06
#
#       Residuos_renovables
# Año
# 2015          816625.6060
# 2016          782912.5340
# 2017          874416.6820
# 2018          871543.0470
# 2019          887446.4720
# 2020          724598.0470
# 2021          875255.7915
# 2022          658616.8380

# %%
df_sum.plot(kind='bar', stacked='True', figsize=(15,8), colormap='tab20')
plt.xlabel('Años')
plt.ylabel('Energia [MWh]')
plt.title(f'Comparativa de energías por año')
plt.legend(loc="lower left",bbox_to_anchor=(1.0,0.4))
plt.savefig(f"images/Comparativa_energias.jpg",bbox_inches='tight',dpi=300)
plt.show()

# %%
renovables=df_sum[['Hidraulica','Turbina_bombeo','Hidroeolica','Eolica','Solar_fotovoltaica','Solar_termica','Otras_renovables','Residuos_renovables']]
renovables.plot(kind='bar', stacked='True', figsize=(15,8))
plt.xlabel('Años')
plt.ylabel('Energia [MWh]')
plt.title('ENERGÍAS RENOVABLES')
plt.legend(loc="lower left",bbox_to_anchor=(1.0,0.7))
plt.savefig(f"images/Energias_renovables_stackedbar.jpg",bbox_inches='tight',dpi=300)
plt.show()

# %%
no_renovables=df_sum[['Nuclear','Carbon','Motores_diesel','Turbina_de_gas','Turbina_de_vapor','Ciclo_combinado','Cogeneracion','Residuos_no_renovables']]
no_renovables.plot(kind='bar', stacked='True', figsize=(15,8))
plt.xlabel('Años')
plt.ylabel('Energia [MWh]')
plt.title('ENERGÍAS NO RENOVABLES')
plt.legend(loc="lower left",bbox_to_anchor=(1.0,0.7))
plt.savefig(f"images/Energias_no_renovables_stackedbar.jpg",bbox_inches='tight',dpi=300)
plt.show()

# %% [markdown]
# `EVOLUCIÓN DE ENERGIAS RENOVABLES VS. NO RENOVABLES`

# %%
renovables=[df_sum.loc[i][['Hidraulica','Turbina_bombeo','Hidroeolica','Eolica','Solar_fotovoltaica','Solar_termica','Otras_renovables','Residuos_renovables']].sum() for i in df_sum.index]
no_renovables=[df_sum.loc[i][['Nuclear','Carbon','Motores_diesel','Turbina_de_gas','Turbina_de_vapor','Ciclo_combinado','Cogeneracion','Residuos_no_renovables']].sum() for i in df_sum.index]

etiquetas=['Renovable','No renovable','Energia_total']


df_energias=pd.DataFrame(zip(renovables, no_renovables), columns=['Renovable', 'No_renovable'])
df_energias['Energia_total']=df_energias['Renovable']+df_energias['No_renovable']
df_energias.index=[str(i) for i in range(2015,2023)]

figure(figsize=(10,2.5), dpi=80)
plt.plot(df_energias['Renovable'], color='green', linewidth=0.5)
plt.plot(df_energias['No_renovable'], color='red', linewidth=0.5)
plt.plot(df_energias['Energia_total'], color='blue', linewidth=0.5)

plt.xlabel('Fecha')
plt.ylabel(f'Energia [MWh]')
plt.title(f'Renovables vs. No renovables')
plt.legend(labels=etiquetas, loc="lower left", bbox_to_anchor=(1,0.6))
plt.savefig(f"images/Comparativa_energias_renov_no_renov.jpg",bbox_inches='tight',dpi=300)
plt.show()

# %%
df_energias['en_renov_1']=df_energias['Renovable']/df_energias['Energia_total']
df_energias['en_no_renov_1']=df_energias['No_renovable']/df_energias['Energia_total']

figure(figsize=(10,2.5), dpi=80)

plt.plot(df_energias['en_renov_1'], color='green', linewidth=0.5)
plt.plot(df_energias['en_no_renov_1'], color='red', linewidth=0.5)

plt.xlabel('Fecha')
plt.ylabel('porcentaje')
plt.title(f'Renovables vs. No renovables')
plt.legend(labels=['Renovable','No renovable'], loc="lower left", bbox_to_anchor=(1,0.85))
plt.show()

# %%
years=list(df_energias.index)
df_energias['en_renov_1']=df_energias['Renovable']/df_energias['Energia_total']
df_energias['en_no_renov_1']=df_energias['No_renovable']/df_energias['Energia_total']
df_energias['años']=years
df_energias
# Out:
#          Renovable  No_renovable  Energia_total  años  en_renov_1  \
# 2015  9.679691e+07  1.700730e+08   2.668699e+08  2015    0.362712
# 2016  1.040980e+08  1.571350e+08   2.612330e+08  2016    0.398487
# 2017  8.653358e+07  1.751450e+08   2.616786e+08  2017    0.330687
# 2018  1.021611e+08  1.582643e+08   2.604254e+08  2018    0.392285
# 2019  9.931971e+07  1.608985e+08   2.602182e+08  2019    0.381678
# 2020  1.129554e+08  1.377249e+08   2.506802e+08  2020    0.450595
# 2021  1.237523e+08  1.356019e+08   2.593542e+08  2021    0.477156
# 2022  8.939055e+07  1.189752e+08   2.083658e+08  2022    0.429008
#
#       en_no_renov_1
# 2015       0.637288
# 2016       0.601513
# 2017       0.669313
# 2018       0.607715
# 2019       0.618322
# 2020       0.549405
# 2021       0.522844
# 2022       0.570992

# %%
figure(figsize=(15,5), dpi=80)
fig, ax = plt.subplots()
df_energias.plot.bar(x ='años', y = ['en_renov_1', 'en_no_renov_1'], ax=ax, figsize=(15,10), color=['green', 'orange'])
plt.title('Porcentaje de producción')
plt.xlabel('Año')
plt.legend(labels=['Renovables','No renovables'], loc="lower left", bbox_to_anchor=(0.86,0.92))
plt.savefig("images/Comparativa_renovable_vs_no_renovable.jpg",bbox_inches='tight',dpi=300)
plt.show()
